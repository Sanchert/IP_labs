# %% [markdown]
# # Multi Layer Perceptron

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  - В теории - достаточно одного скрытого слоя, чтобы закодировать линейную разделимость
#  - возможность закодировать нелинейное разделение
#  - Преположение - применение бОльшего количества слоев позволяет уменьшить общее количество нейронов в них

# %% [markdown]
#  - разная начальная инициализация весов приводит к разному результату, т.к. вычисления производятся
#     над функцией в множесвтом локальных минимумов
#  - гипераметры требуют тщательного подбора: количество слоев,  нейронов в скрытых слоях, количество итераций обучения
#  - восприичив к масштабированию характеристик

# %% [markdown]
# # Gradient Boosting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Осуществляем оптимизацию в направлении наискорейшего спуска
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Про выбор lambda
# ![image.png](attachment:image.png)

# %% [markdown]
# Пример критерия останова
# ![image.png](attachment:image.png)

# %% [markdown]
# Выбор оптимального шага:
# - постоянный
# - с дроблением шага
# - метод наискорейшего спуска (двигаемся вдоль градиента до тех пор, пока не достигнем минимума функции в этой точке)

# %% [markdown]
#  - для обновления весов используется вычисление локального градиента нейрона сети, основанный на разнице значений(эталонного и полученного), и производной функции активации

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Пример
